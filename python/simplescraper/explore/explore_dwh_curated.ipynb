# %%
import duckdb
import pandas as pd
import plotly.express as px
from plotly_calplot import calplot

from common.env_variables import DUCKDB_DWH_FILE


def execute(sql_statement):
    conn = duckdb.connect(DUCKDB_DWH_FILE, read_only=True)
    _df = conn.execute(sql_statement).df()
    conn.close()
    return _df


def display_df(_df):
    with pd.option_context('display.max_rows', None, 'display.max_columns', None, "expand_frame_repr", False,
                           "display.float_format", '${:,.2f}'.format):
        display(_df.fillna('.'))

# %%
execute(f'''
SELECT table_schema,
       table_name,
       table_type
  FROM information_schema.tables
''')
# Out:
#   table_schema                 table_name  table_type
# 0         main            fact_online_job  BASE TABLE
# 1      curated               job_location        VIEW
# 2      curated                        job        VIEW
# 3      curated                 online_job        VIEW
# 4         main  online_job_by_date_change        VIEW
# 5         main                   location        VIEW
# 6         main  job_online_by_date_change        VIEW
# 7         main   count_online_job_by_date        VIEW
# 8         main                top_company        VIEW
# 9         main               top_location        VIEW

# %%
execute(f'''
SELECT *
  FROM curated.online_job
 ORDER BY load_timestamp DESC,
          job_id DESC
 LIMIT 0
''')
# Out:
# Empty DataFrame
# Columns: [job_id, load_timestamp, online_at, url, day, month, year]
# Index: []

# %%
execute(f'''
SELECT *
  FROM curated.job
 ORDER BY load_timestamp DESC,
          job_id DESC
 LIMIT 20
''')
# Out:
#      job_id      load_timestamp  \
# 0   8756987 2022-09-27 22:00:00
# 1   8756986 2022-09-27 22:00:00
# 2   8756985 2022-09-27 22:00:00
# 3   8756984 2022-09-27 22:00:00
# 4   8756983 2022-09-27 22:00:00
# 5   8756982 2022-09-27 22:00:00
# 6   8756981 2022-09-27 22:00:00
# 7   8756980 2022-09-27 22:00:00
# 8   8756979 2022-09-27 22:00:00
# 9   8756978 2022-09-27 22:00:00
# 10  8756977 2022-09-27 22:00:00
# 11  8756976 2022-09-27 22:00:00
# 12  8756975 2022-09-27 22:00:00
# 13  8756974 2022-09-27 22:00:00
# 14  8756973 2022-09-27 22:00:00
# 15  8756972 2022-09-27 22:00:00
# 16  8756971 2022-09-27 22:00:00
# 17  8756970 2022-09-27 22:00:00
# 18  8756969 2022-09-27 22:00:00
# 19  8756968 2022-09-27 22:00:00
#
#                                                 title online_status  \
# 0   Volljurist / Syndikusrechtsanwalt (Rechtsanwal...        online
# 1                         Empfangsmitarbeiter (m/w/d)        online
# 2                     Nachtportier – „Die Nachteule“*        online
# 3   Manager Customer Service Center (m/w/d) | Remo...        online
# 4    Barkeeper / Bartender für die Atrium Bar (m/w/d)        online
# 5         Commis de rang / Servicemitarbeiter (m/w/x)        online
# 6              Servicemitarbeiter "Frühstück" (m/w/d)        online
# 7                           Frühstücksleitung (m/w/x)        online
# 8                          Servicemitarbeiter (m/w/x)        online
# 9                   Guest Service Agent (all genders)        online
# 10  Supervisor Haustechnik / Supervisor Technik (m...        online
# 11                                Chef De Rang(m/w/x)        online
# 12  Leiter Empfang / Front Office Manager in Vollz...        online
# 13                            Ausbildung Koch (m/w/d)        online
# 14                     Kellner / Servicekraft (m/w/d)        online
# 15  Front Office Agent (m/w/d) + 10% fixe Zulage O...        online
# 16  Reservierungsmitarbeiter (m/w/d) ab 01.11.2022...        online
# 17  Frühstückskraft Service (m/w/d) ab 01.10.2022 ...        online
# 18                             Executive Chef (m/w/d)        online
# 19  Chef de Partie (m/w/d) für unser Sternerestaur...        online
#
#     is_anonymous  should_display_early_applicant contract_type work_type  \
# 0          False                           False           NaN       NaN
# 1          False                           False           NaN       NaN
# 2          False                           False           NaN       NaN
# 3          False                           False           NaN       NaN
# 4          False                           False           NaN       NaN
# 5          False                           False           NaN       NaN
# 6          False                           False           NaN       NaN
# 7          False                           False           NaN       NaN
# 8          False                           False           NaN       NaN
# 9          False                           False           NaN       NaN
# 10         False                           False           NaN       NaN
# 11         False                           False           NaN       NaN
# 12         False                           False           NaN       NaN
# 13         False                           False           NaN       NaN
# 14         False                           False           NaN       NaN
# 15         False                           False           NaN       NaN
# 16         False                           False           NaN       NaN
# 17         False                           False           NaN       NaN
# 18         False                           False           NaN       NaN
# 19         False                           False           NaN       NaN
#
#              online_date                              company_name  \
# 0   2022-09-27T20:28:32Z     HypoVereinsbank – Member of UniCredit
# 1   2022-09-27T20:26:59Z                   Motel One München Messe
# 2   2022-09-27T20:26:53Z         Novum Management GmbH the niu Leo
# 3   2022-09-27T20:26:48Z      Deutsche Hospitality Konzernzentrale
# 4   2022-09-27T20:26:43Z                Radisson Blu Hotel, Berlin
# 5   2022-09-27T20:26:37Z                  Steigenberger Inselhotel
# 6   2022-09-27T20:26:32Z                 Vienna House Easy Leipzig
# 7   2022-09-27T20:26:27Z                   Steigenberger Parkhotel
# 8   2022-09-27T20:26:22Z                        IntercityHotel Ulm
# 9   2022-09-27T20:26:16Z         Premier Inn Frankfurt City Centre
# 10  2022-09-27T20:26:11Z             Radisson Blu Hotel, Frankfurt
# 11  2022-09-27T20:26:05Z                  Steigenberger Inselhotel
# 12  2022-09-27T20:25:45Z                  Maritim Hotel Ingolstadt
# 13  2022-09-27T20:25:12Z                  Maritim Hotel Ingolstadt
# 14  2022-09-27T20:23:25Z               MARITIM Hotel Bellevue Kiel
# 15  2022-09-27T20:21:39Z           Crowne Plaza Düsseldorf – Neuss
# 16  2022-09-27T20:21:33Z               Mercure Hotel Hannover City
# 17  2022-09-27T20:21:28Z               Mercure Hotel Hannover City
# 18  2022-09-27T20:21:22Z  Konen & Lorenzen Recruitment Consultants
# 19  2022-09-27T20:21:17Z                         40 SECONDS BERLIN
#
#                              description_introduction  \
# 0   Die HypoVereinsbank ist Teil der UniCredit, ei...
# 1   Unsere Mitarbeiter stehen im Mittelpunkt. Ob a...
# 2   NOVUM Hospitality betreibt als familiengeführt...
# 3   Die fünf Hotelmarken der Deutschen Hospitality...
# 4   Zentral zwischen Alexanderplatz und Museumsins...
# 5   Sie sind fasziniert von Hotellerie und Gastfre...
# 6   Das Vienna House Easy Leipzig, inmitten der In...
# 7   Sie sind fasziniert von Hotellerie und Gastfre...
# 8   Sie wissen, wie vielseitig das Businessleben s...
# 9   Wir sind Premier Inn! Großartige Teams, herzli...
# 10  #EVERY MOMENT MATTERS @ https://careers.radiss...
# 11  Sie sind fasziniert von Hotellerie und Gastfre...
# 12  Interessante Aufgaben, gute Bezahlung und toll...
# 13  Interessante Aufgaben, gute Bezahlung und toll...
# 14  Interessante Aufgaben, gute Bezahlung und toll...
# 15  Mit über 120 Hotels in Deutschland, Belgien un...
# 16  Das Mercure Hotel Hannover City mit seinen 145...
# 17  Du liebst es im Service zu arbeiten und Mensch...
# 18  Für ein exklusives 5-Sterne Hotel im Rheinland...
# 19  40 SECONDS BERLIN ist ein Full-Service-Dienstl...
#
#                          description_responsabilities  \
# 0   Es erwartet Sie eine herausfordernde Tätigkeit...
# 1   Im Fokus steht die professionelle Betreuung un...
# 2   Als „Nachteule“ bist Du während der Nacht erst...
# 3   Markenübergreifende Optimierung/ Vereinfachung...
# 4   Wir, die Radisson Hotel Group, sind ein Teil v...
# 5   Möglichkeit verschiedener Einsatzbereiche:Serv...
# 6   Du bist für das Wohlbefinden unserer Gäste ver...
# 7   Als herzlicher Gastgeber begrüßen und platzier...
# 8   Abwechslungsreiche Aufgaben in einem Team mit ...
# 9   Als Guest Service Agent bzw. Team Member Groun...
# 10  Wir, die Radisson Hotel Group, sind eine der g...
# 11  Betreuung der Kunden vom Erstkontakt bis zur R...
# 12  Verantwortung für einen reibungslosen Ablauf i...
# 13  Ausbildung auf unterschiedlichen Posten: Banke...
# 14  Empfang, Bedienung und Betreuung der Gäste\nSe...
# 15  Wir wissen was es bedeutet, nicht jede Woche d...
# 16  Annahme und Abwicklung von telefonischen und s...
# 17  Betreuung unserer internationalen Gäste währen...
# 18  Verantwortung über das gesamte operative und a...
# 19  Herstellung von Speisen und Produktion in der ...
#
#                              description_requirements  \
# 0   Volljurist:in mit idealerweise zwei Prädikatse...
# 1   Ob als Hotelprofi oder im Quereinstieg – Sie p...
# 2   Du bist ein leidenschaftlicher Gastgeber, der ...
# 3   Sie haben eine Ausbildung bzw. ein Studium im ...
# 4                                   Yes I Can! spirit
# 5   abgeschlossene Ausbildung in der Hotellerie od...
# 6   Du verfügst (wünschenswerterweise) über erste ...
# 7   Idealerweise abgeschlossene Ausbildung  in der...
# 8   Ausbildung oder relevante Berufserfahrung in d...
# 9   Du bist serviceorientiert und hast eine einneh...
# 10                                "Yes I Can!"-Spirit
# 11  abgeschlossene Ausbildung zum Restaurantfachma...
# 12  Abgeschlossene Ausbildung im Hotelbereich\nMeh...
# 13  Praktikum in der Gastronomie oder Erfahrung du...
# 14  Ausbildung in der Hotellerie oder Gastronomie,...
# 15  wünschenswert ist eine Ausbildung im Hotelfach...
# 16  Du hast eine abgeschlossene Ausbildung in der ...
# 17  Du bist Gast- und Serviceorientiert ? \n Du bi...
# 18  Abgeschlossene Berufsausbildung als Koch\nMehr...
