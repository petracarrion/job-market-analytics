# %%
import plotly.express as px

from common.explore import display_sql

# %%
df = display_sql(f'''
SELECT online_at,
       SUM(total_jobs) AS total_jobs
  FROM aggregated_online_job
 WHERE location_name = 'Walldorf'
 GROUP BY 1
 ORDER BY 1
''')

# %%
fig = px.scatter(df, x='online_at', y='total_jobs', trendline='rolling', trendline_options=dict(window=7),
                 title='Number of jobs online (7-day rolling average)')
fig.show('png')

# %%
display_sql(f'''
SELECT company_name,
       SUM(total_jobs) AS total_jobs
  FROM aggregated_online_job
 WHERE company_name ilike '%sap%'
 GROUP BY 1
 ORDER BY 2 DESC
''')
# Out:
#                                          company_name  total_jobs
# 0                               ASAP Engineering GmbH     38497.0
# 1                                   ASAP Holding GmbH     14684.0
# 2                               ASAP Electronics GmbH      6200.0
# 3                                              SAP SE      5782.0
# 4                                   RED SAP Solutions      1077.0
# 5                                         SAPROS GmbH      1031.0
# 6                                              SAP AG      1004.0
# 7                                     SENSAPOLIS GmbH       987.0
# 8                            SAPHIR Maschinenbau GmbH       560.0
# 9                              Sappi Deutschland GmbH       485.0
# 10                                 Sappi Ehingen GmbH       399.0
# 11              Autohaus Max Saparautzki GmbH & Co.KG       311.0
# 12                          Sappi Papier Holding GmbH       310.0
# 13                                            ISAP AG       288.0
# 14                  Landesapothekerkammer Brandenburg       254.0
# 15                                         Misapor AG       240.0
# 16                              sum.cumo Sapiens GmbH       238.0
# 17            Landesapothekerkammer Baden-Württemberg       217.0
# 18                MediosApotheke Anike Oleski e. Kfr.       201.0
# 19                SAPIENTIS GmbH Immobilienverwaltung       196.0
# 20                        Ursapharm Arzneimittel GmbH       185.0
# 21                                     saperatec GmbH       154.0
# 22                           Sapio Life GmbH & Co. KG       153.0
# 23                   Bayerische Landesapothekerkammer       145.0
# 24                                         SAPEK GmbH       143.0
# 25   Versorgungswerk der Landesapothekerkammer Hessen       125.0
# 26                                  Sappi Alfeld GmbH       122.0
# 27                                     sapiens42 GmbH       111.0
# 28               Albert Stetten -asap systems Berlin-        93.0
# 29  SAP ARENA Betriebsgesellschaft der Multifunkti...        93.0
# 30                 SAPROS Handels- und Vertriebs GmbH        93.0
# 31                                 SAPIO Holding GmbH        93.0
# 32  Landesapothekerkammer Hessen Körperschaft des ...        80.0
# 33                            Dosch Messapparate GmbH        67.0
# 34                                 Sappi Biotech GmbH        63.0
# 35                      WISAP Medical Technology GmbH        63.0
# 36                            Saphir Deutschland GmbH        60.0
# 37  Rathausapotheke Pfronten Inh. Peter Engelmann e.K        60.0
# 38                         Sappi Logistics Wesel GmbH        48.0
# 39              Landesapothekerkammer Rheinland-Pfalz        45.0
# 40          Landesapothekerverband Niedersachsen e.V.        38.0
# 41                              Emarsys (Part of SAP)        31.0
# 42                                      ursaPack GmbH        31.0
# 43                               VERSAPAK Europe GmbH        31.0
# 44                           Sapotec Deutschland GmbH        30.0
# 45                             kosaplast GmbH & Co KG        30.0
# 46                            SAPHIR Deutschland GmbH        22.0
# 47                                     Sapherior GmbH        20.0
# 48  Bundesverband Deutscher Krankenhausapotheker (...        19.0
# 49                    Güntherodt Glasapparatebau GmbH        11.0

# %%
df = display_sql(f'''
SELECT online_at,
       SUM(total_jobs) AS total_jobs
  FROM aggregated_online_job
 WHERE company_name = 'SAP SE'
    OR company_name = 'SAP AG'
 GROUP BY 1
 ORDER BY 1
''')

# %%
fig = px.scatter(df, x='online_at', y='total_jobs', trendline='rolling', trendline_options=dict(window=7),
                 title='Number of jobs online (7-day rolling average)')
fig.show('png')
